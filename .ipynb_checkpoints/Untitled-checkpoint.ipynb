# %% [markdown]
# # Basics

# %%
answer = 42
x,y,z = 1,[1:10], "String"
x,y = y, x
# Out:
# (UnitRange{Int64}[1:10], 1)

# %%
const DATE = 2012
# DATE = 10 lỗi
print(DATE)
# Out:
# 2012

# %%
x = y = z = 1
# Out:
# 1

# %%
0<x<3
# Out:
# true

# %%
5<x != y<5
# Out:
# false

# %%
function add(a, b)
    return a+b
end
add(1,2)
# Out:
# 3

# %% [markdown]
# # Operators

# %%
2^3
# Out:
# 8

# %%
1+1
# Out:
# 2

# %%
1-1
# Out:
# 0

# %%
1/2
# Out:
# 0.5

# %%
1\2
# Out:
# 2.0

# %%
7%2
# Out:
# 1

# %%
7 ÷ 2
# Out:
# 3

# %%
!true == false
# Out:
# true

# %%
[1,2,3].*[3,2,2] #nhân element-wise
# Out:
# 3-element Vector{Int64}:
#  3
#  4
#  6

# %%
[1,2,3] .+[2,3,4] # cộng element-wise
# Out:
# 3-element Vector{Int64}:
#  3
#  5
#  7

# %%
a = "String"
b = "String"
a===b # so sánh object
# Out:
# true

# %% [markdown]
# # Characters and strings

# %%
chr ='C'
# Out:
# 'C': ASCII/Unicode U+0043 (category Lu: Letter, uppercase)

# %%
str = "A string"
# Out:
# "A string"

# %%
Int('A')
# Out:
# 65

# %%
Char(65)
# Out:
# 'A': ASCII/Unicode U+0041 (category Lu: Letter, uppercase)

# %%
chr = '\u0000'
# Out:
# '\0': ASCII/Unicode U+0000 (category Cc: Other, control)

# %%
for i in str
    println(i)
end
# Out:
# A
#
# s
# t
# r
# i
# n
# g

# %%
str = "Hello"*", World"
# Out:
# "Hello, World"

# %%
replace("Hello","e" =>"a")
# Out:
# "Hallo"

# %%
lastindex("Hello")
# Out:
# 5

# %%
length("hello")
# Out:
# 5

# %% [markdown]
# # Random Numbers

# %%
# lấy ngẫu nhiên số bất kì theo phân phối đều [0,1)
rand()
# Out:
# 0.429646571490071

# %%
# tạo ngẫu nhiên ma trận 3x2 theo phân phối chuẩn
randn(3,2)
# Out:
# 3×2 Matrix{Float64}:
#  1.58851   -1.03391
#  1.09558   -0.445543
#  0.962098   0.721721

# %%
using Distributions

# %%
# random vector 10 chiều theo phân phối khác ví dụ Bernoulli
my_dist = Bernoulli(0.2)
rand(my_dist,10)
# Out:
# 10-element Vector{Bool}:
#  0
#  0
#  1
#  1
#  0
#  0
#  0
#  0
#  1
#  0

# %%
using Random

# %%
# lấy ngẫu nhiên từ một array với xác suất p
A = [1,2,3,4,5,6]
p = 0.2
print(randsubseq(A,p))
# Out:
# [1]

# %%
# xáo trộn array
shuffle(A)
# Out:
# 6-element Vector{Int64}:
#  5
#  3
#  4
#  2
#  1
#  6

# %% [markdown]
# # Arrays

# %%
# tạo một mảng
arr = Float64[]
# Out:
# Float64[]
